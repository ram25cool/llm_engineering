# %% [markdown]
# # Stock data analysis

# %%
import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %% [markdown]
# # Connecting to OpenAI

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
openai = OpenAI()

# %%
from urllib.parse import urlencode
import datetime

headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

# %%
import yfinance as yf
class YahooFinanceWebsite:
    def stock_analysis(stock_symbol):
        
        self.stock_symbol = stock_symbol.upper()
        title = "Google share analysis"
        ticker = yf.Ticker("GOOG")
        data = ticker.history(period="1y", interval="1wk")
        #print(data)
    
        return data

    '''def __build_url(self, params):
        #base_url = f"https://finance.yahoo.com/quote/{self.stock_symbol}/history/"
        base_url = f"https://finance.yahoo.com/quote/GOOG/history/"
        query_string = urlencode(params)
        return f"{base_url}?{query_string}"

    def get_stock_data(self):
        datetime_now = datetime.datetime.now()
        datetime_year_ago = datetime_now - datetime.timedelta(days=365)
        params = {"frequency": "1wk", "period1": datetime_year_ago.timestamp(), "period2": datetime_now.timestamp()}
        url = self.__build_url(params)
        response = requests.get(url, headers=headers)

        print(response)

        soup = BeautifulSoup(response.content, 'html.parser')

        print(soup)
        title = soup.title.string if soup.title else "No title found"
        print(title)
        if soup.body:
            for irrelevant in soup.body.find_all(["script", "style", "img", "input"]):
                irrelevant.decompose()

        html_table_data = soup.find("table")'''

# %%
def build_stock_analysis_prompt(stock_symbol, title, stock_table_data):
    sys_prompt = r"""You are an assistant that analyzes the contents of HTML formated table that contains data on a specific stock.
    The HTML table contains the date, open price, close price, low and highs aggregated for every week over one year timeframe.
    Ignoring text, tags or html attributes that might be navigation related. 
    Respond in Markdown format"""
    
    user_prompt = f"The data provided below in the HTML table format for {stock_symbol} from the Yahoo Finances.\
    Make the explaination easy enough for a newbie to understand. \
    Analyze and Summarize the trends on this stock:\n{stock_table_data}\n\n\
    Also, calculate the total returns in percentage one could have expected over this period."
    
    return [
        {"role": "system", "content": sys_prompt},
        {"role": "user", "content": user_prompt}
    ]

# %%
def analyze_stock_trends(stock_symbol):
    stock_data_page = YahooFinanceWebsite()
    title, stock_table_data = stock_data_page.stock_analysis()
    response = openai.chat.completions.create(
        model = "gpt-4o-mini",
        messages = build_stock_analysis_prompt(stock_symbol, title, stock_table_data)
    )
    return response.choices[0].message.content

def display_analysis(stock_symbol):
    display(Markdown(analyze_stock_trends(stock_symbol)))

# %%
display_analysis("GOOG")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 display_analysis("GOOG")
#
# Cell In[60], line 11, in display_analysis(stock_symbol)
#      10 def display_analysis(stock_symbol):
# ---> 11     display(Markdown(analyze_stock_trends(stock_symbol)))
#
# Cell In[60], line 3, in analyze_stock_trends(stock_symbol)
#       1 def analyze_stock_trends(stock_symbol):
#       2     stock_data_page = YahooFinanceWebsite()
# ----> 3     title, stock_table_data = stock_data_page.get_stock_data()
#       4     response = openai.chat.completions.create(
#       5         model = "gpt-4o-mini",
#       6         messages = build_stock_analysis_prompt(stock_symbol, title, stock_table_data)
#       7     )
#       8     return response.choices[0].message.content
#
# AttributeError: 'YahooFinanceWebsite' object has no attribute 'get_stock_data'

# %%
# !pip install yfinance
import yfinance as yf

ticker = yf.Ticker("GOOG")
data = ticker.history(period="1y", interval="1wk")
print(data)
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.65-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from yfinance) (2.3.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from yfinance) (2.32.4)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from yfinance) (4.3.8)
# Requirement already satisfied: pytz>=2022.5 in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from yfinance) (2025.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.6-py312-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.2.tar.gz (949 kB)
#      ---------------------------------------- 0.0/949.2 kB ? eta -:--:--
#      ------------------------------------- 949.2/949.2 kB 14.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from yfinance) (4.13.4)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from yfinance) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.14.1)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.7.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from requests>=2.31->yfinance) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Requirement already satisfied: six>=1.5 in c:\users\vaibhav\personal\ai_ml\llm_engineering\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Downloading yfinance-0.2.65-py2.py3-none-any.whl (119 kB)
# Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 21.5 MB/s eta 0:00:00
# Downloading frozendict-2.4.6-py312-none-any.whl (16 kB)
# Building wheels for collected packages: multitasking, peewee
#   Building wheel for multitasking (pyproject.toml): started
#   Building wheel for multitasking (pyproject.toml): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15703 sha256=3ef32a1f98734f0a091997b0579447aa1322c39effb2167f9b3726cb229db713
#   Stored in directory: c:\users\vaibhav\appdata\local\pip\cache\wheels\cc\bd\6f\664d62c99327abeef7d86489e6631cbf45b56fbf7ef1d6ef00
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.18.2-py3-none-any.whl size=139153 sha256=3f0120c04303cb4a54852b73bb9bc68c07d976c5f393652399acad2fb25bd8f8
#   Stored in directory: c:\users\vaibhav\appdata\local\pip\cache\wheels\d1\df\a9\0202b051c65b11c992dd6db9f2babdd2c44ec7d35d511be5d3
# Successfully built multitasking peewee
# Installing collected packages: peewee, multitasking, frozendict, curl_cffi, yfinance
# Successfully installed curl_cffi-0.13.0 frozendict-2.4.6 multitasking-0.0.12 peewee-3.18.2 yfinance-0.2.65
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#                                  Open        High         Low       Close  \
# Date
# 2024-08-19 00:00:00-04:00  166.192166  168.610548  164.241523  166.630051
# 2024-08-26 00:00:00-04:00  167.351586  168.570739  161.208076  164.321136
# 2024-09-02 00:00:00-04:00  162.534710  162.599402  151.209077  151.403152
# 2024-09-09 00:00:00-04:00  152.895984  158.514002  147.491920  157.613327
# 2024-09-16 00:00:00-04:00  157.780960  164.417869  157.063456  164.069077
# 2024-09-23 00:00:00-04:00  164.766657  166.391010  161.468137  164.716827
# 2024-09-30 00:00:00-04:00  164.208588  169.848965  164.069074  167.975479
# 2024-10-07 00:00:00-04:00  168.553468  169.310827  160.561275  163.949493
# 2024-10-14 00:00:00-04:00  164.338132  168.503629  163.799996  164.477646
# 2024-10-21 00:00:00-04:00  164.009273  167.018804  162.205552  166.410919
# 2024-10-28 00:00:00-04:00  169.998446  183.152670  165.215088  172.051300
# 2024-11-04 00:00:00-05:00  170.646194  181.946867  168.897275  179.236298
# 2024-11-11 00:00:00-05:00  179.445580  183.386852  172.145969  173.287003
# 2024-11-18 00:00:00-05:00  174.348319  179.545232  164.736761  165.992401
# 2024-11-25 00:00:00-05:00  167.407458  170.900293  166.819492  169.898788
# 2024-12-02 00:00:00-05:00  169.729388  177.093761  169.679559  175.877991
# 2024-12-09 00:00:00-05:00  175.105654  196.207226  174.791743  190.716339
# 2024-12-16 00:00:00-05:00  193.910733  202.405831  185.934409  192.509018
# 2024-12-23 00:00:00-05:00  193.576516  197.696868  191.182131  193.586487
# 2024-12-30 00:00:00-05:00  190.418929  194.045428  188.268967  192.678635
# 2025-01-06 00:00:00-05:00  194.693905  201.667574  191.152214  192.718536
# 2025-01-13 00:00:00-05:00  190.902796  198.345352  188.219080  197.088303
# 2025-01-20 00:00:00-05:00  200.041380  203.363600  196.360017  201.428131
# 2025-01-27 00:00:00-05:00  193.736155  206.596028  192.159845  205.119492
# 2025-02-03 00:00:00-05:00  201.742386  208.212230  184.667396  186.702621
# 2025-02-10 00:00:00-05:00  188.618142  189.545977  183.200840  186.433258
# 2025-02-17 00:00:00-05:00  187.001929  187.341131  180.706679  181.155624
# 2025-02-24 00:00:00-05:00  183.370427  184.657405  167.996439  171.817490
# 2025-03-03 00:00:00-05:00  173.323965  176.486555  167.148430  175.339249
# 2025-03-10 00:00:00-04:00  169.762313  170.051629  162.858488  167.228241
# 2025-03-17 00:00:00-04:00  167.124121  168.257769  158.609362  166.050415
# 2025-03-24 00:00:00-04:00  169.061783  172.702411  155.152507  155.872635
# 2025-03-31 00:00:00-04:00  154.624142  160.082577  147.362865  147.562637
# 2025-04-07 00:00:00-04:00  143.217845  161.675654  142.488726  159.208618
# 2025-04-14 00:00:00-04:00  162.115140  163.833077  150.718835  153.175888
# 2025-04-21 00:00:00-04:00  150.783750  168.038019  148.221827  163.653290
# 2025-04-28 00:00:00-04:00  164.062789  166.499862  156.966324  165.610931
# 2025-05-05 00:00:00-04:00  164.317483  166.899386  149.310528  154.194656
# 2025-05-12 00:00:00-04:00  158.909002  170.445124  157.390823  167.228989
# 2025-05-19 00:00:00-04:00  165.516050  177.916154  164.062795  169.386398
# 2025-05-26 00:00:00-04:00  171.094344  176.268118  168.322667  172.642487
# 2025-06-02 00:00:00-04:00  168.807083  175.618903  166.479879  174.709991
# 2025-06-09 00:00:00-04:00  175.658856  182.225975  173.361629  175.668854
# 2025-06-16 00:00:00-04:00  175.904999  178.714996  166.270004  167.729996
# 2025-06-23 00:00:00-04:00  167.320007  178.839996  163.330002  178.270004
# 2025-06-30 00:00:00-04:00  180.785004  181.580002  174.660004  180.550003
# 2025-07-07 00:00:00-04:00  180.134995  182.610001  173.880005  181.309998
# 2025-07-14 00:00:00-04:00  182.070007  187.360001  180.710999  185.940002
# 2025-07-21 00:00:00-04:00  187.100006  198.970001  187.050003  194.080002
# 2025-07-28 00:00:00-04:00  194.410004  198.479996  188.699997  189.949997
# 2025-08-04 00:00:00-04:00  191.175003  203.429993  190.919998  202.089996
# 2025-08-11 00:00:00-04:00  201.554993  207.330002  198.639999  204.910004
# 2025-08-18 00:00:00-04:00  205.070007  206.139999  197.460007  200.901596
#
#                               Volume  Dividends  Stock Splits
# Date
# 2024-08-19 00:00:00-04:00   48675000       0.00           0.0
# 2024-08-26 00:00:00-04:00   76549800       0.00           0.0
# 2024-09-02 00:00:00-04:00   83082400       0.00           0.0
# 2024-09-09 00:00:00-04:00  105165700       0.20           0.0
# 2024-09-16 00:00:00-04:00  106889800       0.00           0.0
# 2024-09-23 00:00:00-04:00   79869200       0.00           0.0
# 2024-09-30 00:00:00-04:00   67871000       0.00           0.0
# 2024-10-07 00:00:00-04:00   69271500       0.00           0.0
# 2024-10-14 00:00:00-04:00   62984300       0.00           0.0
# 2024-10-21 00:00:00-04:00   63427700       0.00           0.0
# 2024-10-28 00:00:00-04:00  154027500       0.00           0.0
# 2024-11-04 00:00:00-05:00   87525700       0.00           0.0
# 2024-11-11 00:00:00-05:00   80173600       0.00           0.0
# 2024-11-18 00:00:00-05:00  113121900       0.00           0.0
# 2024-11-25 00:00:00-05:00   58017300       0.00           0.0
# 2024-12-02 00:00:00-05:00   80019700       0.00           0.0
# 2024-12-09 00:00:00-05:00  139950700       0.20           0.0
# 2024-12-16 00:00:00-05:00  156317400       0.00           0.0
# 2024-12-23 00:00:00-05:00   44646600       0.00           0.0
# 2024-12-30 00:00:00-05:00   56984900       0.00           0.0
# 2025-01-06 00:00:00-05:00   71539200       0.00           0.0
# 2025-01-13 00:00:00-05:00   75273900       0.00           0.0
# 2025-01-20 00:00:00-05:00   62385800       0.00           0.0
# 2025-01-27 00:00:00-05:00   84829000       0.00           0.0
# 2025-02-03 00:00:00-05:00  139053600       0.00           0.0
# 2025-02-10 00:00:00-05:00   72709900       0.00           0.0
# 2025-02-17 00:00:00-05:00   64501100       0.00           0.0
# 2025-02-24 00:00:00-05:00  119184000       0.00           0.0
# 2025-03-03 00:00:00-05:00  109159100       0.00           0.0
# 2025-03-10 00:00:00-04:00  106394000       0.20           0.0
# 2025-03-17 00:00:00-04:00  117275200       0.00           0.0
# 2025-03-24 00:00:00-04:00  111520100       0.00           0.0
# 2025-03-31 00:00:00-04:00  139064600       0.00           0.0
# 2025-04-07 00:00:00-04:00  187459400       0.00           0.0
# 2025-04-14 00:00:00-04:00   70381600       0.00           0.0
# 2025-04-21 00:00:00-04:00  116569400       0.00           0.0
# 2025-04-28 00:00:00-04:00   96215100       0.00           0.0
# 2025-05-05 00:00:00-04:00  165989500       0.00           0.0
# 2025-05-12 00:00:00-04:00  147587400       0.00           0.0
# 2025-05-19 00:00:00-04:00  170493300       0.00           0.0
# 2025-05-26 00:00:00-04:00  107773500       0.00           0.0
# 2025-06-02 00:00:00-04:00  116271800       0.00           0.0
# 2025-06-09 00:00:00-04:00  108939100       0.21           0.0
# 2025-06-16 00:00:00-04:00  123723000       0.00           0.0
# 2025-06-23 00:00:00-04:00  187875500       0.00           0.0
# 2025-06-30 00:00:00-04:00  102356400       0.00           0.0
# 2025-07-07 00:00:00-04:00  125057400       0.00           0.0
# 2025-07-14 00:00:00-04:00  108742400       0.00           0.0
# 2025-07-21 00:00:00-04:00  161299900       0.00           0.0
# 2025-07-28 00:00:00-04:00  127684300       0.00           0.0
# 2025-08-04 00:00:00-04:00   96820400       0.00           0.0
# 2025-08-11 00:00:00-04:00   95005700       0.00           0.0
# 2025-08-18 00:00:00-04:00   45829359       0.00           0.0
